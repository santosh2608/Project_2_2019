# %%
# Import libs
import requests
import pprint
import numpy as np
import pandas as pd
import json
from sqlalchemy import create_engine

# %%
# API base URL
url = "http://api.worldbank.org/v2/"
# csv file path
country_gdp_file = "../Resources/country_gdp.csv"
country_pop_file = "../Resources/country_pop.csv"

format = "json"

# Get country information in JSON format
data = requests.get(f"{url}countries?format={format}").json()
pprint.pprint(data[1])
# Out:
# [{'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Oranjestad',
#   'id': 'ABW',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AW',
#   'latitude': '12.5167',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-70.0167',
#   'name': 'Aruba',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#   'capitalCity': 'Kabul',
#   'id': 'AFG',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'AF',
#   'latitude': '34.5228',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '69.1761',
#   'name': 'Afghanistan',
#   'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'AFR',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'A9',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Africa',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Luanda',
#   'id': 'AGO',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'AO',
#   'latitude': '-8.81155',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '13.242',
#   'name': 'Angola',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Tirane',
#   'id': 'ALB',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AL',
#   'latitude': '41.3317',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '19.8172',
#   'name': 'Albania',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Andorra la Vella',
#   'id': 'AND',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AD',
#   'latitude': '42.5075',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '1.5218',
#   'name': 'Andorra',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'ANR',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'L5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Andean Region',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'ARB',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': '1A',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Arab World',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Abu Dhabi',
#   'id': 'ARE',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AE',
#   'latitude': '24.4764',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '54.3705',
#   'name': 'United Arab Emirates',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Buenos Aires',
#   'id': 'ARG',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AR',
#   'latitude': '-34.6118',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-58.4173',
#   'name': 'Argentina',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Yerevan',
#   'id': 'ARM',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AM',
#   'latitude': '40.1596',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '44.509',
#   'name': 'Armenia',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Pago Pago',
#   'id': 'ASM',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AS',
#   'latitude': '-14.2846',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-170.691',
#   'name': 'American Samoa',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': "Saint John's",
#   'id': 'ATG',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AG',
#   'latitude': '17.1175',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-61.8456',
#   'name': 'Antigua and Barbuda',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Canberra',
#   'id': 'AUS',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AU',
#   'latitude': '-35.282',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '149.129',
#   'name': 'Australia',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Vienna',
#   'id': 'AUT',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AT',
#   'latitude': '48.2201',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '16.3798',
#   'name': 'Austria',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Baku',
#   'id': 'AZE',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AZ',
#   'latitude': '40.3834',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '49.8932',
#   'name': 'Azerbaijan',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Bujumbura',
#   'id': 'BDI',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'BI',
#   'latitude': '-3.3784',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '29.3639',
#   'name': 'Burundi',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BEA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B4',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia & Pacific (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BEC',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B7',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe & Central Asia (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Brussels',
#   'id': 'BEL',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BE',
#   'latitude': '50.8371',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '4.36761',
#   'name': 'Belgium',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Porto-Novo',
#   'id': 'BEN',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'BJ',
#   'latitude': '6.4779',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '2.6323',
#   'name': 'Benin',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Ouagadougou',
#   'id': 'BFA',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'BF',
#   'latitude': '12.3605',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '-1.53395',
#   'name': 'Burkina Faso',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#   'capitalCity': 'Dhaka',
#   'id': 'BGD',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'BD',
#   'latitude': '23.7055',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '90.4113',
#   'name': 'Bangladesh',
#   'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Sofia',
#   'id': 'BGR',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BG',
#   'latitude': '42.7105',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '23.3238',
#   'name': 'Bulgaria',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BHI',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B1',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IBRD countries classified as high income',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Manama',
#   'id': 'BHR',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BH',
#   'latitude': '26.1921',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '50.5354',
#   'name': 'Bahrain',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Nassau',
#   'id': 'BHS',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BS',
#   'latitude': '25.0661',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-77.339',
#   'name': 'Bahamas, The',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Sarajevo',
#   'id': 'BIH',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BA',
#   'latitude': '43.8607',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '18.4214',
#   'name': 'Bosnia and Herzegovina',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BLA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B2',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Latin America & the Caribbean (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Minsk',
#   'id': 'BLR',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BY',
#   'latitude': '53.9678',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '27.5766',
#   'name': 'Belarus',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Belmopan',
#   'id': 'BLZ',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BZ',
#   'latitude': '17.2534',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-88.7713',
#   'name': 'Belize',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BMN',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B3',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Middle East & North Africa (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Hamilton',
#   'id': 'BMU',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BM',
#   'latitude': '32.3293',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-64.706',
#   'name': 'Bermuda',
#   'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'La Paz',
#   'id': 'BOL',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'BO',
#   'latitude': '-13.9908',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-66.1936',
#   'name': 'Bolivia',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Brasilia',
#   'id': 'BRA',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BR',
#   'latitude': '-15.7801',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-47.9292',
#   'name': 'Brazil',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Bridgetown',
#   'id': 'BRB',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BB',
#   'latitude': '13.0935',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-59.6105',
#   'name': 'Barbados',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Bandar Seri Begawan',
#   'id': 'BRN',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BN',
#   'latitude': '4.94199',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '114.946',
#   'name': 'Brunei Darussalam',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BSS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#   'capitalCity': 'Thimphu',
#   'id': 'BTN',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'BT',
#   'latitude': '27.5768',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '89.6177',
#   'name': 'Bhutan',
#   'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Gaborone',
#   'id': 'BWA',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BW',
#   'latitude': '-24.6544',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '25.9201',
#   'name': 'Botswana',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CAA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C9',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Bangui',
#   'id': 'CAF',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'CF',
#   'latitude': '5.63056',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '21.6407',
#   'name': 'Central African Republic',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Ottawa',
#   'id': 'CAN',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CA',
#   'latitude': '45.4215',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-75.6919',
#   'name': 'Canada',
#   'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CEA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C4',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia and the Pacific (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CEB',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B8',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Central Europe and the Baltics',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CEU',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe and Central Asia (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Bern',
#   'id': 'CHE',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CH',
#   'latitude': '46.948',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '7.44821',
#   'name': 'Switzerland',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CHI',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'JG',
#   'latitude': '',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '',
#   'name': 'Channel Islands',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Santiago',
#   'id': 'CHL',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CL',
#   'latitude': '-33.475',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-70.6475',
#   'name': 'Chile',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Beijing',
#   'id': 'CHN',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'CN',
#   'latitude': '40.0495',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '116.286',
#   'name': 'China',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}}]

# %%
# read csv file from specified folder
country_gdp_df = pd.read_csv(country_gdp_file)
country_pop_df = pd.read_csv(country_pop_file)

# clean up data and creating dataframe with required columns
clean_gdp_df = country_gdp_df[['Country Code', '2018_gdp']].copy()
clean_pop_df = country_pop_df[['Country Code', '2018_pop']].copy()

# replace NaN data with 0
clean_gdp_df['2018_gdp'] = clean_gdp_df['2018_gdp'].replace(np.nan, 0)
clean_pop_df['2018_pop'] = clean_pop_df['2018_pop'].replace(np.nan, 0)

# merge two dataset to one dataframe
gdp_pop_df = pd.merge(clean_gdp_df, clean_pop_df, on=['Country Code', 'Country Code'])
gdp_pop_df.head()
# Out:
#   Country Code      2018_gdp    2018_pop
# 0          ABW  0.000000e+00    105845.0
# 1          AFG  1.936297e+10  37172386.0
# 2          AGO  1.060000e+11  30809762.0
# 3          ALB  1.505888e+10   2866376.0
# 4          AND  3.236544e+09     77006.0

# %%
# define veriables

ids = []
incomeLevel = []
country = []
lat = []
lon = []
country_name = []
region = []

world_data_df = pd.DataFrame()

# append required json data
for world_data in data[1]:
    ids.append(world_data["id"])
    country_name.append(world_data["name"])
    region.append(world_data["region"]["value"])
    incomeLevel.append(world_data["incomeLevel"]["value"])
    lat.append(world_data["latitude"])
    lon.append(world_data["longitude"])
    
    
# create dataset from required fields
world_data_df["Country Code"] = ids
world_data_df["country_name"] = country_name
world_data_df["region"] = region
world_data_df["income_level"] = incomeLevel
world_data_df["latitude"] = lat
world_data_df["longitude"] = lon

# drop duplicate records
world_data_df.drop_duplicates()

# replace latitude and longitude empty value with 0
world_data_df['latitude'] = world_data_df['latitude'].replace('', 0)
world_data_df['longitude'] = world_data_df['longitude'].replace('', 0)

# merge dataframe by country code and create one data frame
world_income_df = pd.merge(world_data_df, gdp_pop_df, on=['Country Code', 'Country Code'])
world_income_df.head()
# Out:
#   Country Code country_name                      region         income_level  \
# 0          ABW        Aruba  Latin America & Caribbean           High income
# 1          AFG  Afghanistan                  South Asia           Low income
# 2          AGO       Angola         Sub-Saharan Africa   Lower middle income
# 3          ALB      Albania       Europe & Central Asia  Upper middle income
# 4          AND      Andorra       Europe & Central Asia          High income
#
#    latitude longitude      2018_gdp    2018_pop
# 0   12.5167  -70.0167  0.000000e+00    105845.0
# 1   34.5228   69.1761  1.936297e+10  37172386.0
# 2  -8.81155    13.242  1.060000e+11  30809762.0
# 3   41.3317   19.8172  1.505888e+10   2866376.0
# 4   42.5075    1.5218  3.236544e+09     77006.0

# %%
# Create connection to local database
rds_connection_string = "postgres:postgres@127.0.0.1:5432/world_income_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Get table name available on database
engine.table_names()
# Out:
# ['world_income']

# %%
# insert dataframe data to world_income table
world_income_df.to_sql(name='world_income', con=engine, if_exists='append', index=False)

# %%
# get data from world_income table
pd.read_sql_query('select * from world_income', con=engine).head()
# Out:
#   Country Code country_name                      region         income_level  \
# 0          ABW        Aruba  Latin America & Caribbean           High income
# 1          AFG  Afghanistan                  South Asia           Low income
# 2          AGO       Angola         Sub-Saharan Africa   Lower middle income
# 3          ALB      Albania       Europe & Central Asia  Upper middle income
# 4          AND      Andorra       Europe & Central Asia          High income
#
#    latitude  longitude      2018_gdp    2018_pop
# 0  12.51670   -70.0167  0.000000e+00    105845.0
# 1  34.52280    69.1761  1.936297e+10  37172386.0
# 2  -8.81155    13.2420  1.060000e+11  30809762.0
# 3  41.33170    19.8172  1.505888e+10   2866376.0
# 4  42.50750     1.5218  3.236544e+09     77006.0
